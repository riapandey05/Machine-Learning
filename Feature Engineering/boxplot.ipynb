# %% [markdown]
# 5 number summary and box plot

# %%
# minimum,maximum,median,q1,q3,iqr

# %%
import numpy as np

# %%
lst_marks = [45, 78, 88, 56, 90, 67, 89, 76, 55, 99, 100, 34, 23, 45, 67, 89, 90]
minimum,Q1,median,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (23.0, 55.0, 76.0, 89.0, 100.0)

# %%
iqr=Q3-Q1
print(iqr)
# Out:
# 34.0

# %%
# any value below lower fence or above upper fence is an outlier
lower_fence = Q1 - 1.5*iqr
upper_fence = Q3 + 1.5*iqr

# %%
print(lower_fence)
# Out:
# 4.0

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks2 = [45, 78, 88, 56, 90, 67, 89, 76, 55, 34, 23, 45, 67, 89, 90,200,300,-50,-100]

# %%
sns.boxplot(lst_marks2)
# Out:
# <Axes: >
